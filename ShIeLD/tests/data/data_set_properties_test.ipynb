# %%
import pickle
from pathlib import Path

# %%
requirements = {
    "path_raw_data": Path.cwd()/'shield_test.csv',
    "path_to_data_set": Path.cwd() / 'data_set',
    "path_training_results": Path.cwd()/ 'training_results',
    "path_to_model":Path.cwd().parent/'model',
    "path_to_interaction_plots": Path.cwd().parent / 'cTc_interactions',

    'cell_type_names': ['Endothelial_cells', 'Fibroblasts', 'Adipocytes', 'Muscular_cells',
                        'Norlike', 'B_cells', 'Preneo', 'Schwann_cells', 'Basal_cells',
                        'MoMac', 'Prolif_cells', 'Low_features', 'Luminal_cells', 'CD4',
                        'Immune_Epi_doublet', 'Plasma_cells', 'Neutrophils', 'NK_cells',
                        'Mature_DC', 'Langherans_cells', 'cDC2', 'cDC1', 'CD8',
                        'ISG_cells', 'Unknown', 'pDC', 'Treg'],

    'markers': ['Abca8a', 'Abcc9', 'Abhd17c', 'Ace','Ace2', 'Ache',
                'Ackr1', 'Ackr3', 'Acod1', 'Actc1', 'Actn2', 'Acvrl1',
                'Adamdec1', 'Adcy8', 'Adcyap1r1', 'Adgra2', 'Adgre1', 
                'Adgrf5','Adgrv1', 'Wwtr1', 'Yeats4', 'Zbp1', 'Zfp819'],

    'label_dict': {'early': 0,
                   'normal': 1},
    'label_column': 'condition',

    'eval_columns': ['cell_type', 'condition', 'sample'],

    'col_of_interest': ['anker_value', 'radius_distance', 'fussy_limit',
                        'droupout_rate', 'comment', 'comment_norm', 'model_no', 'split_number'],
    'col_of_variables': ['droupout_rate', 'fussy_limit', 'anker_value', 'radius_distance', 'comment', 'comment_norm'],
    'sampleing':'voroni',

    'minimum_number_cells': 50,
    'radius_distance_all': [25, 55, 75],
    'fussy_limit_all': [0.1, 0.5],
    'anker_value_all': [0.03, 0.08],

    'filter_column': None,
    'filter_value': None,
    'filter_cells': False,

    'anker_cell_selction_type': '%',  # either % or absolut
    'multiple_labels_per_subSample': False,

    'droupout_rate': [0.2],
    'input_layer': 23,
    'batch_size': 10,
    'learning_rate': 1e-2,
    'patience': 2,

    'output_layer': 2,
    'layer_1': 56,
    'attr_bool': False,

    'augmentation_number': 5,
    'X_col_name': 'spatial_dim0',
    'Y_col_name': 'spatial_dim1',
    'measument_sample_name': 'sample',

    'validation_split_column': 'fold',
    'number_validation_splits': [1,2,3,4, 5],
    'test_set_fold_number': [0],
    'voro_neighbours': 10,
}

# %%
pickle.dump(requirements, open(Path.cwd()/ 'requirements.pt', 'wb'))
